# %% [markdown]
# 1. Use boston_housees.csv and take only 'RM' and 'Price' of the houses.Divide the data as training and testing data.Fit the line using Ridge Regression and find the price of a house if it contains 6.5 rooms

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge,LinearRegression

# %%
# Load the dataset into df
df = pd.read_csv('/Users/hackthebox/Downloads/Machine-Learning-Self-Study/Regression/Ridge_Regression/Data/boston_houses.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
# take RM (5th column) into x and convert into 2D array
x = df.iloc[:,5:6].values

# %%
# take Price (last column) into y and convert into 1D array
y = df.iloc[:,-1].values

# %%
# Split the data into train and test data
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# draw scatter plot for train and test data in the same graph
plt.scatter(x_train,y_train,color='blue',marker='^')
plt.scatter(x_test,y_test,color='red',marker='+')
plt.show()

# %%
# Using Simple Linear Regression on fit train data
lr = LinearRegression()
lr.fit(x_train,y_train) 
lr.score(x_train,y_train)
# Out:
# 0.5050658352776293

# %%
# Display the train data with regression line
plt.scatter(x_train,y_train,color='blue',marker='^')
plt.plot(x_train,lr.predict(x_train),color='red')
plt.show()

# %%
# Using Ridge Regression on fit a line for test data
rr = Ridge(alpha=0.01)
rr.fit(x_test,y_test)
rr.score(x_test,y_test)
# Out:
# 0.3816963643539958

# %%
# Display the test data with regression line
plt.scatter(x_test,y_test,color='red',marker='+')
plt.plot(x_test,rr.predict(x_test),color='green')
plt.show()

# %%
# predict price of a house having 6.5 rooms
rr.predict([[6.5]])
# Out:
# array([24.20412567])
