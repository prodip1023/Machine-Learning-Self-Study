# %% [markdown]
# 1. Apply DecisionTreeClassifier Machine Learning Model to take a decision wehether to play cricket or not under given conditions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
import numpy as np
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/hackthebox/Downloads/Machine-Learning-Self-Study/DECISION_TREES/Data/cricket1.csv')
df.head()
# Out:
#     Outlook Temperature Humidity  Windy Play Cricket
# 0     Sunny         Hot     High  False           No
# 1     Sunny         Hot     High   True           No
# 2  Overcast         Hot     High  False          Yes
# 3     Rainy        Mild     High  False          Yes
# 4     Rainy        Cool   Normal  False          Yes

# %% [markdown]
# - All independent columns values are text so first step is convert text to numeric use of label encoder.

# %% [markdown]
# - Outlook column :
#  * Suuny - 2
#  * Overcast - 0
#  * Rainy - 1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Outlook_n'] = le.fit_transform(df['Outlook'])
df['Temp_n'] = le.fit_transform(df['Temperature'])
df['Humidity_n'] = le.fit_transform(df['Humidity'])
df['Windy_n'] = le.fit_transform(df['Windy'])
df['Play_n'] = le.fit_transform(df['Play Cricket'])

# %%
df
# Out:
#      Outlook Temperature Humidity  Windy Play Cricket  Outlook_n  Temp_n  \
# 0      Sunny         Hot     High  False           No          2       1
# 1      Sunny         Hot     High   True           No          2       1
# 2   Overcast         Hot     High  False          Yes          0       1
# 3      Rainy        Mild     High  False          Yes          1       2
# 4      Rainy        Cool   Normal  False          Yes          1       0
# 5      Rainy        Cool   Normal   True           No          1       0
# 6   Overcast        Cool   Normal   True          Yes          0       0
# 7      Sunny        Mild     High  False           No          2       2
# 8      Sunny        Cool   Normal  False          Yes          2       0
# 9      Rainy        Mild   Normal  False          Yes          1       2
# 10     Sunny        Mild   Normal   True          Yes          2       2
# 11  Overcast        Mild     High   True          Yes          0       2
# ...

# %% [markdown]
# #### Remove text values columns

# %%
df = df.drop(['Outlook','Temperature','Humidity','Windy','Play Cricket'],axis='columns')

# %%
df
# Out:
#     Outlook_n  Temp_n  Humidity_n  Windy_n  Play_n
# 0           2       1           0        0       0
# 1           2       1           0        1       0
# 2           0       1           0        0       1
# 3           1       2           0        0       1
# 4           1       0           1        0       1
# 5           1       0           1        1       0
# 6           0       0           1        1       1
# 7           2       2           0        0       0
# 8           2       0           1        0       1
# 9           1       2           1        0       1
# 10          2       2           1        1       1
# 11          0       2           0        1       1
# 12          0       1           1        0       1
# 13          1       2           0        1       0

# %% [markdown]
# #### Divided independent(x) and dependent variable(y)

# %%
x = df.drop(['Play_n'],axis='columns')
y = df['Play_n']

# %% [markdown]
# #### Create Decision tree classification

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# - default criterion - "gini" - gini index

# %%
model_1 = DecisionTreeClassifier(criterion='entropy')
model_1.fit(x,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
model.predict([[2,1,0,0]])
# Out:
# array([0])

# %%
model_1.predict([[2,1,0,0]])
# Out:
# array([0])

# %% [markdown]
# - can not play
