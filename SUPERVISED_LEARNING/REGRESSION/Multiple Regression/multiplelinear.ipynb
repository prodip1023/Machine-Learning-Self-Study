# %% [markdown]
# <div style="text-align: center; color: yellow; font-size: 24px; font-weight: bold;">
#     MULTIPLE LINEAR REGRESSION
# </div>

# %% [markdown]
# - In Simple Linear Regression Model , we take only 1 independent variable (x) that is useful to predict the dependent variable (y) value.
# - For example,'area' of the house is useful to predict the house 'price'.
# - But in many practical cases,house 'price' does not dependent only 'area'.The price of a house can decide depending on various factor like 'area','the number of bedrooms','the age of the house' etc.These variables are called independent variables and they are useful to predict the price of house.
# - When we use multiple (more than 1) variables in Linear Regression Model.It is called 'Multiple Linear Regression Model'.
# - In 'Multiple Linear Regression', the target variable (y) value can be calculated based on several independent variables (x1,x2,x3,....) so the equation used by this model will be form of:

# %% [markdown]
# y = m1 x x1 + m2 x x2 + m3 x x3 + ...........+ b

# %% [markdown]
# - Here,y is called the dependent variable or target variable.
# - x1,x2,x3 are called independent variables or features.
# - m1,m2,m3 are called slope
# - b is called intercept

# %% [markdown]
# (![image.png](attachment:image.png))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
homeprice = pd.read_csv('/Users/hackthebox/Downloads/Machine-Learning-Self-Study/Regression/Multiple Regression/Data/homeprices.csv')

# %%
homeprice.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %% [markdown]
# - We supposed to calculate the home 'price' depending on 'area','bedrooms' and 'age' columns.So Multiple Linear Regression Model uses the following equation:

# %% [markdown]
# y = m1 x x1 + m2 x x2 + m3 x x3 + ...........+ b
#
# price = m1 x area + m2 x bredrooms + m3 x age +b
