# %% [markdown]
# - Optuna is a open-source hyperparameter optimization framework designed by Machine Learning.
# - Optuna supports various optimization algorithms and integrates with popular machine learning libraries like scikit-learn,Tensorflow,PyTorch and XGBoost.

# %% [markdown]
# - https://xgboost.readthedocs.io/en/stable/install.html#python
# - https://optuna.readthedocs.io/en/stable/installation.html
# - https://optuna.readthedocs.io/en/stable/tutorial/20_recipes/012_artifact_tutorial.html
# - https://github.com/dmlc/xgboost/blob/master/doc/parameter.rst

# %%
# !pip install optuna
# !pip install xgboost
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.0.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import optuna
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/content/Admission_Predict.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  ...  LOR   CGPA  Research  Chance of Admit
# 0           1        337          118                  4  ...   4.5  9.65         1              0.92
# 1           2        324          107                  4  ...   4.5  8.87         1              0.76
# 2           3        316          104                  3  ...   3.5  8.00         1              0.72
# 3           4        322          110                  3  ...   2.5  8.67         1              0.80
# 4           5        314          103                  2  ...   3.0  8.21         0              0.65
#
# [5 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.drop('Serial No.',axis=1,inplace=True)

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  Chance of Admit
# 0        337          118                  4  4.5   4.5  9.65         1              0.92
# 1        324          107                  4  4.0   4.5  8.87         1              0.76
# 2        316          104                  3  3.0   3.5  8.00         1              0.72
# 3        322          110                  3  3.5   2.5  8.67         1              0.80
# 4        314          103                  2  2.0   3.0  8.21         0              0.65

# %%
X = df.drop('Chance of Admit ', axis=1)
y = df['Chance of Admit ']

# %%
X.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0

# %%
y.head()
# Out:
# 0    0.92
# 1    0.76
# 2    0.72
# 3    0.80
# 4    0.65
# Name: Chance of Admit , dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %% [markdown]
# # Implementation optuna

# %%
def objective(trial,data=X,target=y):
  train_X,test_X,train_y,test_y = train_test_split(data,target,test_size=0.25,random_state=42)
  params = {
      'tree_method':'auto',
      'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
      'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
      'colsample_bytree':trial.suggest_categorical('colsample_bytree',[0.5,0.7,0.9,1.0]),
      'subsample':trial.suggest_categorical('subsample',[0.5,0.7,0.9,1.0]),
      'learning_rate':trial.suggest_categorical('learning_rate',[0.001,0.01,0.1,0.2,0.3]),
      'n_estimators':trial.suggest_categorical('n_estimators',[100,200,300,400,500]),
      'max_depth':trial.suggest_categorical('max_depth',[3,5,7,9,12,15,17,20]),
      'random_state':trial.suggest_categorical('random_state',[24,48,2020,30,3423,232123,2321]),
      'min_child_weight':trial.suggest_int('min_child_weight',1,10),
      'gamma':trial.suggest_int('gamma',0,10),
      'eval_metric':['rmse']
  }
  model = xgb.XGBRegressor(**params)
  model.fit(train_X,train_y,eval_set=[(test_X,test_y)],verbose=False)
  preds = model.predict(test_X)
  rmse = np.sqrt(mean_squared_error(test_y,preds))
  return rmse

# %%
# optuna
find_params = optuna.create_study(direction='minimize')
find_params.optimize(objective,n_trials=100)
print('Number of finished trials: {}'.format(len(find_params.trials)))
print('Best trial:')
trial = find_params.best_trial
print('  Value: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
  print('    {}: {}'.format(key, value))
# Out:
# [I 2024-11-10 18:44:35,102] A new study created in memory with name: no-name-49c98d77-68ee-48ee-b00e-3e28354cdf10
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:35,302] Trial 0 finished with value: 0.12542605188610834 and parameters: {'lambda': 0.022188737495766178, 'alpha': 0.00023465818439947204, 'colsample_bytree': 0.9, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 500, 'max_depth': 5, 'random_state': 2020, 'min_child_weight': 6, 'gamma': 1}. Best is trial 0 with value: 0.12542605188610834.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:35,407] Trial 1 finished with value: 0.15379218443378107 and parameters: {'lambda': 0.0015342188312960838, 'alpha': 0.0016052384602913824, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.3, 'n_estimators': 200, 'max_depth': 20, 'random_state': 2321, 'min_child_weight': 7, 'gamma': 3}. Best is trial 0 with value: 0.12542605188610834.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:35,556] Trial 2 finished with value: 0.1537857550296315 and parameters: {'lambda': 1.3914995356958209, 'alpha': 0.0010643321087045318, 'colsample_bytree': 0.5, 'subsample': 0.9, 'learning_rate': 0.1, 'n_estimators': 400, 'max_depth': 9, 'random_state': 2020, 'min_child_weight': 1, 'gamma': 7}. Best is trial 0 with value: 0.12542605188610834.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:35,724] Trial 3 finished with value: 0.1538024394665357 and parameters: {'lambda': 0.0005209309098037532, 'alpha': 0.03204572287855869, 'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.01, 'n_estimators': 500, 'max_depth': 20, 'random_state': 232123, 'min_child_weight': 10, 'gamma': 9}. Best is trial 0 with value: 0.12542605188610834.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:35,902] Trial 4 finished with value: 0.1538026294185101 and parameters: {'lambda': 0.00012799921380784361, 'alpha': 0.5189470159038074, 'colsample_bytree': 0.9, 'subsample': 0.9, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 9, 'random_state': 48, 'min_child_weight': 6, 'gamma': 5}. Best is trial 0 with value: 0.12542605188610834.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:36,041] Trial 5 finished with value: 0.1289066509917442 and parameters: {'lambda': 0.14305188155685059, 'alpha': 0.33843631669904894, 'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.001, 'n_estimators': 300, 'max_depth': 3, 'random_state': 2020, 'min_child_weight': 7, 'gamma': 0}. Best is trial 0 with value: 0.12542605188610834.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:36,214] Trial 6 finished with value: 0.11728859356579223 and parameters: {'lambda': 9.283089542938423, 'alpha': 0.12341773625925875, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.3, 'n_estimators': 500, 'max_depth': 12, 'random_state': 232123, 'min_child_weight': 6, 'gamma': 1}. Best is trial 6 with value: 0.11728859356579223.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:36,283] Trial 7 finished with value: 0.1538024394665357 and parameters: {'lambda': 0.0005268409685190779, 'alpha': 3.1482564709398138, 'colsample_bytree': 0.9, 'subsample': 0.9, 'learning_rate': 0.3, 'n_estimators': 100, 'max_depth': 7, 'random_state': 48, 'min_child_weight': 3, 'gamma': 3}. Best is trial 6 with value: 0.11728859356579223.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:36,500] Trial 8 finished with value: 0.15379373144764633 and parameters: {'lambda': 0.0037967771381222895, 'alpha': 0.03940853964120501, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.01, 'n_estimators': 500, 'max_depth': 7, 'random_state': 3423, 'min_child_weight': 10, 'gamma': 8}. Best is trial 6 with value: 0.11728859356579223.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:36,632] Trial 9 finished with value: 0.15396160128559866 and parameters: {'lambda': 0.0006082601260580694, 'alpha': 0.44304456631843736, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.2, 'n_estimators': 400, 'max_depth': 20, 'random_state': 2020, 'min_child_weight': 4, 'gamma': 5}. Best is trial 6 with value: 0.11728859356579223.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:36,733] Trial 10 finished with value: 0.1538024394665357 and parameters: {'lambda': 9.997035790768063, 'alpha': 5.453853459247179, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.3, 'n_estimators': 100, 'max_depth': 12, 'random_state': 232123, 'min_child_weight': 8, 'gamma': 2}. Best is trial 6 with value: 0.11728859356579223.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:37,090] Trial 11 finished with value: 0.1116642770378923 and parameters: {'lambda': 0.03403678817118315, 'alpha': 0.00013278293465484578, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 500, 'max_depth': 5, 'random_state': 30, 'min_child_weight': 4, 'gamma': 0}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:37,512] Trial 12 finished with value: 0.11239919202198184 and parameters: {'lambda': 0.24502591362098536, 'alpha': 0.0069132741297270595, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 500, 'max_depth': 15, 'random_state': 30, 'min_child_weight': 4, 'gamma': 0}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:38,023] Trial 13 finished with value: 0.11193032752207116 and parameters: {'lambda': 0.11352255169922401, 'alpha': 0.0032177782792918884, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 500, 'max_depth': 15, 'random_state': 30, 'min_child_weight': 3, 'gamma': 0}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:38,155] Trial 14 finished with value: 0.1538032706603565 and parameters: {'lambda': 0.02075417384386968, 'alpha': 0.0002926553228153151, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 300, 'max_depth': 5, 'random_state': 30, 'min_child_weight': 1, 'gamma': 3}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:38,408] Trial 15 finished with value: 0.1340664517051623 and parameters: {'lambda': 0.13039532078281021, 'alpha': 0.003879753752782172, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 200, 'max_depth': 17, 'random_state': 30, 'min_child_weight': 3, 'gamma': 0}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:38,604] Trial 16 finished with value: 0.1363066628797421 and parameters: {'lambda': 0.6455447339751833, 'alpha': 0.0006643577173855848, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.1, 'n_estimators': 500, 'max_depth': 15, 'random_state': 24, 'min_child_weight': 3, 'gamma': 2}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:38,800] Trial 17 finished with value: 0.15374510415997455 and parameters: {'lambda': 0.010024137346061392, 'alpha': 0.00011964340072853086, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.2, 'n_estimators': 500, 'max_depth': 5, 'random_state': 30, 'min_child_weight': 4, 'gamma': 7}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:39,015] Trial 18 finished with value: 0.15379651646060016 and parameters: {'lambda': 0.0560641535274669, 'alpha': 0.006465125320721975, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.001, 'n_estimators': 500, 'max_depth': 15, 'random_state': 30, 'min_child_weight': 2, 'gamma': 4}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:39,141] Trial 19 finished with value: 0.15380144812830066 and parameters: {'lambda': 1.5958215371929287, 'alpha': 0.00010230291709695018, 'colsample_bytree': 1.0, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 200, 'max_depth': 3, 'random_state': 2321, 'min_child_weight': 5, 'gamma': 10}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:39,405] Trial 20 finished with value: 0.13547063433178244 and parameters: {'lambda': 0.006108493370552872, 'alpha': 0.0029392863254363777, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 300, 'max_depth': 17, 'random_state': 24, 'min_child_weight': 2, 'gamma': 1}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:40,993] Trial 21 finished with value: 0.11255940338901368 and parameters: {'lambda': 0.26251056808098805, 'alpha': 0.015676047540916033, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 500, 'max_depth': 15, 'random_state': 30, 'min_child_weight': 4, 'gamma': 0}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:43,086] Trial 22 finished with value: 0.11187606646804676 and parameters: {'lambda': 0.04996362113192258, 'alpha': 0.01036719711450952, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 500, 'max_depth': 15, 'random_state': 30, 'min_child_weight': 5, 'gamma': 0}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:43,302] Trial 23 finished with value: 0.14035783638327962 and parameters: {'lambda': 0.04945478920924591, 'alpha': 0.0005370770809987152, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.001, 'n_estimators': 500, 'max_depth': 15, 'random_state': 30, 'min_child_weight': 5, 'gamma': 2}. Best is trial 11 with value: 0.1116642770378923.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:43,404] Trial 24 finished with value: 0.10811824636345341 and parameters: {'lambda': 0.0759265509522897, 'alpha': 0.01385189854190786, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 2, 'gamma': 1}. Best is trial 24 with value: 0.10811824636345341.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:43,502] Trial 25 finished with value: 0.10835746644508855 and parameters: {'lambda': 0.012869942937531144, 'alpha': 0.09525405310414048, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 2, 'gamma': 1}. Best is trial 24 with value: 0.10811824636345341.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:43,607] Trial 26 finished with value: 0.1538633046246598 and parameters: {'lambda': 0.012444403675459587, 'alpha': 0.090144969305493, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 2, 'gamma': 4}. Best is trial 24 with value: 0.10811824636345341.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:43,725] Trial 27 finished with value: 0.1419260329529638 and parameters: {'lambda': 0.002734517849948587, 'alpha': 1.5790803346295847, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 1, 'gamma': 1}. Best is trial 24 with value: 0.10811824636345341.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:43,832] Trial 28 finished with value: 0.12852913865339363 and parameters: {'lambda': 0.011448444204121923, 'alpha': 0.11201030905753183, 'colsample_bytree': 0.9, 'subsample': 1.0, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 2, 'gamma': 2}. Best is trial 24 with value: 0.10811824636345341.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:43,937] Trial 29 finished with value: 0.11666826867999293 and parameters: {'lambda': 0.024913965436276775, 'alpha': 1.0797639570457713, 'colsample_bytree': 0.9, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 2, 'gamma': 1}. Best is trial 24 with value: 0.10811824636345341.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:44,043] Trial 30 finished with value: 0.15382510539558172 and parameters: {'lambda': 0.001762768871138898, 'alpha': 0.18480494273958958, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 1, 'gamma': 4}. Best is trial 24 with value: 0.10811824636345341.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:44,158] Trial 31 finished with value: 0.10811346441048722 and parameters: {'lambda': 0.0520764332045779, 'alpha': 0.014286715170395582, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 5, 'gamma': 1}. Best is trial 31 with value: 0.10811346441048722.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:44,279] Trial 32 finished with value: 0.10821969524461914 and parameters: {'lambda': 0.03158810777367471, 'alpha': 0.04991024424627782, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 7, 'gamma': 1}. Best is trial 31 with value: 0.10811346441048722.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:44,418] Trial 33 finished with value: 0.12868441627039662 and parameters: {'lambda': 0.08358660458627379, 'alpha': 0.05650702187930531, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 8, 'gamma': 2}. Best is trial 31 with value: 0.10811346441048722.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:44,526] Trial 34 finished with value: 0.10820217778355373 and parameters: {'lambda': 0.3369924531912045, 'alpha': 0.019305486967458485, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 7, 'gamma': 1}. Best is trial 31 with value: 0.10811346441048722.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:44,629] Trial 35 finished with value: 0.15386171348036065 and parameters: {'lambda': 0.7707377917032155, 'alpha': 0.019350623299972204, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 9, 'random_state': 3423, 'min_child_weight': 7, 'gamma': 6}. Best is trial 31 with value: 0.10811346441048722.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:44,748] Trial 36 finished with value: 0.15381947910654808 and parameters: {'lambda': 0.3751121173916263, 'alpha': 0.02004913263172222, 'colsample_bytree': 1.0, 'subsample': 0.9, 'learning_rate': 0.1, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 8, 'gamma': 3}. Best is trial 31 with value: 0.10811346441048722.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:44,852] Trial 37 finished with value: 0.13012987009652302 and parameters: {'lambda': 4.909476873217318, 'alpha': 0.041981748743551754, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 20, 'random_state': 2321, 'min_child_weight': 7, 'gamma': 2}. Best is trial 31 with value: 0.10811346441048722.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:45,031] Trial 38 finished with value: 0.1104600235233074 and parameters: {'lambda': 1.3545822854702407, 'alpha': 0.0015284139630616595, 'colsample_bytree': 0.5, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 400, 'max_depth': 3, 'random_state': 48, 'min_child_weight': 9, 'gamma': 1}. Best is trial 31 with value: 0.10811346441048722.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:45,131] Trial 39 finished with value: 0.15380771257272552 and parameters: {'lambda': 0.189730292426507, 'alpha': 0.21939190508546075, 'colsample_bytree': 0.9, 'subsample': 0.9, 'learning_rate': 0.01, 'n_estimators': 100, 'max_depth': 5, 'random_state': 3423, 'min_child_weight': 6, 'gamma': 3}. Best is trial 31 with value: 0.10811346441048722.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:45,259] Trial 40 finished with value: 0.10811176297719442 and parameters: {'lambda': 0.0877823949544345, 'alpha': 0.010793177204056292, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 7, 'random_state': 3423, 'min_child_weight': 7, 'gamma': 1}. Best is trial 40 with value: 0.10811176297719442.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:45,397] Trial 41 finished with value: 0.10813929393565624 and parameters: {'lambda': 0.0728083011139161, 'alpha': 0.02086531494294164, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 7, 'random_state': 3423, 'min_child_weight': 7, 'gamma': 1}. Best is trial 40 with value: 0.10811176297719442.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:45,503] Trial 42 finished with value: 0.10811103047518049 and parameters: {'lambda': 0.0893349013935314, 'alpha': 0.010436612284092555, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 7, 'random_state': 3423, 'min_child_weight': 9, 'gamma': 1}. Best is trial 42 with value: 0.10811103047518049.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:45,607] Trial 43 finished with value: 0.1538021926978318 and parameters: {'lambda': 0.08826419951778129, 'alpha': 0.009172446520741147, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.2, 'n_estimators': 100, 'max_depth': 7, 'random_state': 2020, 'min_child_weight': 9, 'gamma': 3}. Best is trial 42 with value: 0.10811103047518049.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:45,742] Trial 44 finished with value: 0.13697958400849886 and parameters: {'lambda': 0.05468892794445038, 'alpha': 0.003965443947208561, 'colsample_bytree': 0.7, 'subsample': 0.9, 'learning_rate': 0.3, 'n_estimators': 200, 'max_depth': 7, 'random_state': 232123, 'min_child_weight': 9, 'gamma': 2}. Best is trial 42 with value: 0.10811103047518049.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:46,038] Trial 45 finished with value: 0.07772235430938673 and parameters: {'lambda': 0.15044995763110006, 'alpha': 0.012362111401301, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.2, 'n_estimators': 400, 'max_depth': 7, 'random_state': 3423, 'min_child_weight': 8, 'gamma': 0}. Best is trial 45 with value: 0.07772235430938673.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:46,295] Trial 46 finished with value: 0.06803930587430264 and parameters: {'lambda': 0.16124415742579742, 'alpha': 0.0019738325598793144, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 7, 'random_state': 3423, 'min_child_weight': 10, 'gamma': 0}. Best is trial 46 with value: 0.06803930587430264.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:46,556] Trial 47 finished with value: 0.06737130853823942 and parameters: {'lambda': 0.6381146339595846, 'alpha': 0.002237765536991968, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 7, 'random_state': 48, 'min_child_weight': 10, 'gamma': 0}. Best is trial 47 with value: 0.06737130853823942.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:46,799] Trial 48 finished with value: 0.06719821276467274 and parameters: {'lambda': 0.55934322852119, 'alpha': 0.0019106409677235507, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 7, 'random_state': 24, 'min_child_weight': 10, 'gamma': 0}. Best is trial 48 with value: 0.06719821276467274.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# ...
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:57,808] Trial 84 finished with value: 0.12522860363947957 and parameters: {'lambda': 0.3460254125421543, 'alpha': 0.002828992654918551, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 17, 'random_state': 24, 'min_child_weight': 10, 'gamma': 1}. Best is trial 80 with value: 0.06717435246271045.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:57,987] Trial 85 finished with value: 0.07605825181082047 and parameters: {'lambda': 0.336266020832684, 'alpha': 0.004813814120206354, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.3, 'n_estimators': 200, 'max_depth': 9, 'random_state': 24, 'min_child_weight': 10, 'gamma': 0}. Best is trial 80 with value: 0.06717435246271045.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:58,258] Trial 86 finished with value: 0.06835035548115946 and parameters: {'lambda': 0.12629255232845765, 'alpha': 0.0021592582825431033, 'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 12, 'random_state': 24, 'min_child_weight': 10, 'gamma': 0}. Best is trial 80 with value: 0.06717435246271045.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:58,449] Trial 87 finished with value: 0.12525758599249998 and parameters: {'lambda': 0.4279905882038489, 'alpha': 0.0029967882824888962, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 12, 'random_state': 24, 'min_child_weight': 10, 'gamma': 1}. Best is trial 80 with value: 0.06717435246271045.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:58,602] Trial 88 finished with value: 0.1529462760375683 and parameters: {'lambda': 0.17123190704100244, 'alpha': 0.007839873149801628, 'colsample_bytree': 0.9, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 300, 'max_depth': 20, 'random_state': 24, 'min_child_weight': 10, 'gamma': 2}. Best is trial 80 with value: 0.06717435246271045.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:58,867] Trial 89 finished with value: 0.06780412493997547 and parameters: {'lambda': 0.21538118546115742, 'alpha': 0.003962318369305834, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 12, 'random_state': 2321, 'min_child_weight': 10, 'gamma': 0}. Best is trial 80 with value: 0.06717435246271045.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:59,045] Trial 90 finished with value: 0.12559434115032106 and parameters: {'lambda': 0.49049761517069057, 'alpha': 0.0013930847969908441, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 12, 'random_state': 232123, 'min_child_weight': 10, 'gamma': 1}. Best is trial 80 with value: 0.06717435246271045.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:59,297] Trial 91 finished with value: 0.06717301206412896 and parameters: {'lambda': 0.2949055792485847, 'alpha': 0.000879844925341833, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 12, 'random_state': 24, 'min_child_weight': 10, 'gamma': 0}. Best is trial 91 with value: 0.06717301206412896.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:59,560] Trial 92 finished with value: 0.06727924200962952 and parameters: {'lambda': 0.3422977685967851, 'alpha': 0.0008825742357208484, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 12, 'random_state': 24, 'min_child_weight': 10, 'gamma': 0}. Best is trial 91 with value: 0.06717301206412896.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:44:59,843] Trial 93 finished with value: 0.06730398502278223 and parameters: {'lambda': 0.30765696744026816, 'alpha': 0.0008239535464135333, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 12, 'random_state': 24, 'min_child_weight': 10, 'gamma': 0}. Best is trial 91 with value: 0.06717301206412896.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:45:00,092] Trial 94 finished with value: 0.06721116977316575 and parameters: {'lambda': 0.27332825677055206, 'alpha': 0.0008602146735612542, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 12, 'random_state': 24, 'min_child_weight': 10, 'gamma': 0}. Best is trial 91 with value: 0.06717301206412896.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:45:00,361] Trial 95 finished with value: 0.06718316230385886 and parameters: {'lambda': 0.27954203541490763, 'alpha': 0.0008981120865365895, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 12, 'random_state': 24, 'min_child_weight': 10, 'gamma': 0}. Best is trial 91 with value: 0.06717301206412896.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:45:00,535] Trial 96 finished with value: 0.12106645742506483 and parameters: {'lambda': 0.11950672673142546, 'alpha': 0.0010214347296869481, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.1, 'n_estimators': 400, 'max_depth': 3, 'random_state': 24, 'min_child_weight': 10, 'gamma': 1}. Best is trial 91 with value: 0.06717301206412896.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:45:00,849] Trial 97 finished with value: 0.06762520009437506 and parameters: {'lambda': 0.25733698283753587, 'alpha': 0.0008739143491695143, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 500, 'max_depth': 12, 'random_state': 2020, 'min_child_weight': 10, 'gamma': 0}. Best is trial 91 with value: 0.06717301206412896.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:45:01,023] Trial 98 finished with value: 0.12522782144325503 and parameters: {'lambda': 0.35604402280934, 'alpha': 0.001684837710272443, 'colsample_bytree': 0.5, 'subsample': 0.5, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 15, 'random_state': 24, 'min_child_weight': 10, 'gamma': 1}. Best is trial 91 with value: 0.06717301206412896.
# <ipython-input-60-93b3d0ac5cfe>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda':trial.suggest_loguniform('lambda',1e-4,10.0),
# <ipython-input-60-93b3d0ac5cfe>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha':trial.suggest_loguniform('alpha',1e-4,10.0),
# [I 2024-11-10 18:45:01,218] Trial 99 finished with value: 0.15380156443691834 and parameters: {'lambda': 0.18466767671490705, 'alpha': 0.0012720059259197338, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.01, 'n_estimators': 400, 'max_depth': 12, 'random_state': 24, 'min_child_weight': 10, 'gamma': 8}. Best is trial 91 with value: 0.06717301206412896.
# Number of finished trials: 100
# Best trial:
#   Value: 0.06717301206412896
#   Params:
#     lambda: 0.2949055792485847
#     alpha: 0.000879844925341833
#     colsample_bytree: 0.5
#     subsample: 0.5
#     learning_rate: 0.01
#     n_estimators: 400
#     max_depth: 12
#     random_state: 24
#     min_child_weight: 10
#     gamma: 0

# %%
best_params = {
    'lambda':0.2949055792485847,
    'alpha': 0.000879844925341833,
    'colsample_bytree': 0.5,
    'subsample': 0.5,
    'learning_rate': 0.1,
    'n_estimators': 400,
    'max_depth': 12,
    'random_state': 24,
    'min_child_weight': 10,
    'gamma': 0
}

# %%
# !pip show optuna
# Out:
# Name: optuna
# Version: 4.0.0
# Summary: A hyperparameter optimization framework
# Home-page: https://optuna.org/
# Author: Takuya Akiba
# Author-email:
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: alembic, colorlog, numpy, packaging, PyYAML, sqlalchemy, tqdm
# Required-by:

# %%
model = xgb.XGBRegressor(**best_params)
model.fit(X_train_sc,y_train)
y_pred = model.predict(X_test_sc)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred) # xgb
# Out:
# 0.7760574470925321

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor()
model2.fit(X_train_sc,y_train)
y_pred2 = model2.predict(X_test_sc)
r2_score(y_test,y_pred2) # rf
# Out:
# 0.8052636956662638

# %%
X_train_sc[0]
# Out:
# array([-0.51832699, -0.57399919, -0.95044085, -0.85046036,  0.05717854,
#        -0.18943738, -1.0762311 ])

# %%
# save the model with pickle file
import pickle
pickle.dump(model,open('model.pkl','wb'))

# %%
# load the model and predict
model = pickle.load(open('model.pkl','rb'))
model.predict([[500,150,5,5,5.3,9.5,1]])
# Out:
# array([0.96152633], dtype=float32)

# %% [markdown]
# GRE Score= 500	TOEFL Score=150	University Rating=5	SOP=5	LOR=5.3	CGPA=9.5 Research=1
